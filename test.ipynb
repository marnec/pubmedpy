# %%
import pubmedpy as pm
from xml.etree import ElementTree
from bs4 import BeautifulSoup
import re
import requests
import pandas as pd

# %%
article = pm.parse_article('examples/example0.xml')
# Out:
# Paragraph(i=1, Text(Lung disorders have significant morbidity and mortality rates worldwide, both in humans and in animals. Acute respiratory distress syndrome (ARDS) is one of the leading causes of respiratory failure around the world. Although early diagnosis, timely medical care, and treatment may lead to improvement of symptoms, the signs return after a period of time. Causes of ARDS are different. It can be caused by direct or indirect damage to the lung epithelium. ARDS is described by severe hypoxemia, decreased pulmonary compliance, diffuse alveolar damage, and bilateral pulmonary infiltrates after cardiac edema [), ReferencedContent(href=None, text=1), Text(, ), ReferencedContent(href=None, text=2), Text(] and confirmed by a combination of clinical, physiological, and chest imaging parameters. Pulmonary inflammation with disruption of the mechanism of the alveolar–capillary barrier is an important direct cause of ARDS [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=4), Text(]. Therapeutic approaches include mechanical ventilation, neuromuscular blocking agents, fluid management, drug and antimicrobial therapy, and prone positioning [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=6), Text(]. These therapeutic strategies have a supportive role and cannot prevent the progression of the disease [), ReferencedContent(href=None, text=7), Text(–), ReferencedContent(href=None, text=10), Text(]. The ultimate approach is lung transplant, but it has many problems for recipient patients such as lack of suitable donors and the use of immunosuppressive drugs over a lifetime to prevent rejection of the transplant [), ReferencedContent(href=None, text=11), Text(]. Therefore, the recognition of new therapeutic approaches such as stromal cell therapy is essential [), ReferencedContent(href=None, text=12), Text(]. MSCs confer immunomodulatory and anti-inflammatory effects, enhance bacterial clearance, reduce cell injury and death, and are angiogenic [), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=13), Text(]. The mechanism of the MSCs’ effects includes several pathways mediated through differentiation, proliferation, soluble intermediate release, extracellular vesicles, transfer of organelles, and direct cell-to-cell contact, which decrease activation of inflammatory cell secretion of paracrine mediators [), ReferencedContent(href=None, text=14), Text(, ), ReferencedContent(href=None, text=15), Text(]. Recent studies have shown positive effects of MSC-based therapy for ARDS. Induction of inflammation by the LPS of ), Text(Escherichia coli), Text( O55:B5 is one of the best and simplest methods for making an experimental model of ARDS. Although the ARDS animal models cannot reflect human ARDS accurately, the rabbit model is similar and hence suitable for translating the results from pilot to clinical conditions [), ReferencedContent(href=None, text=16), Text(]. Anatomical, physiological, genetic, and biochemical similarity to humans simulates human lung disease, and as the rabbit is easy to handle, it is considered as a suitable model for pulmonary research [), ReferencedContent(href=None, text=17), Text(, ), ReferencedContent(href=None, text=18), Text(]. Moreover, the rabbit serves as an excellent platform for treatment based on stromal cells [), ReferencedContent(href=None, text=19), Text(, ), ReferencedContent(href=None, text=20), Text(]. Thus, in this study, the rabbit was used as a model for causing ARDS, and then it was treated with stromal cells. The aim of this study was evaluation of therapeutic potential intrapulmonary administration of BM-MSCs in an experimental model of ), Text(E. coli), Text( LPS-induced ARDS in the rabbit.))
#
# Section(title='Background', content=[Paragraph(i=2, Text(Lung disorders have significant morbidity and mortality rates worldwide, both in humans and in animals. Acute respiratory distress syndrome (ARDS) is one of the leading causes of respiratory failure around the world. Although early diagnosis, timely medical care, and treatment may lead to improvement of symptoms, the signs return after a period of time. Causes of ARDS are different. It can be caused by direct or indirect damage to the lung epithelium. ARDS is described by severe hypoxemia, decreased pulmonary compliance, diffuse alveolar damage, and bilateral pulmonary infiltrates after cardiac edema [), ReferencedContent(href=None, text=1), Text(, ), ReferencedContent(href=None, text=2), Text(] and confirmed by a combination of clinical, physiological, and chest imaging parameters. Pulmonary inflammation with disruption of the mechanism of the alveolar–capillary barrier is an important direct cause of ARDS [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=4), Text(]. Therapeutic approaches include mechanical ventilation, neuromuscular blocking agents, fluid management, drug and antimicrobial therapy, and prone positioning [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=6), Text(]. These therapeutic strategies have a supportive role and cannot prevent the progression of the disease [), ReferencedContent(href=None, text=7), Text(–), ReferencedContent(href=None, text=10), Text(]. The ultimate approach is lung transplant, but it has many problems for recipient patients such as lack of suitable donors and the use of immunosuppressive drugs over a lifetime to prevent rejection of the transplant [), ReferencedContent(href=None, text=11), Text(]. Therefore, the recognition of new therapeutic approaches such as stromal cell therapy is essential [), ReferencedContent(href=None, text=12), Text(]. MSCs confer immunomodulatory and anti-inflammatory effects, enhance bacterial clearance, reduce cell injury and death, and are angiogenic [), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=13), Text(]. The mechanism of the MSCs’ effects includes several pathways mediated through differentiation, proliferation, soluble intermediate release, extracellular vesicles, transfer of organelles, and direct cell-to-cell contact, which decrease activation of inflammatory cell secretion of paracrine mediators [), ReferencedContent(href=None, text=14), Text(, ), ReferencedContent(href=None, text=15), Text(]. Recent studies have shown positive effects of MSC-based therapy for ARDS. Induction of inflammation by the LPS of ), Text(Escherichia coli), Text( O55:B5 is one of the best and simplest methods for making an experimental model of ARDS. Although the ARDS animal models cannot reflect human ARDS accurately, the rabbit model is similar and hence suitable for translating the results from pilot to clinical conditions [), ReferencedContent(href=None, text=16), Text(]. Anatomical, physiological, genetic, and biochemical similarity to humans simulates human lung disease, and as the rabbit is easy to handle, it is considered as a suitable model for pulmonary research [), ReferencedContent(href=None, text=17), Text(, ), ReferencedContent(href=None, text=18), Text(]. Moreover, the rabbit serves as an excellent platform for treatment based on stromal cells [), ReferencedContent(href=None, text=19), Text(, ), ReferencedContent(href=None, text=20), Text(]. Thus, in this study, the rabbit was used as a model for causing ARDS, and then it was treated with stromal cells. The aim of this study was evaluation of therapeutic potential intrapulmonary administration of BM-MSCs in an experimental model of ), Text(E. coli), Text( LPS-induced ARDS in the rabbit.))])
# Paragraph(i=2, Text(Lung disorders have significant morbidity and mortality rates worldwide, both in humans and in animals. Acute respiratory distress syndrome (ARDS) is one of the leading causes of respiratory failure around the world. Although early diagnosis, timely medical care, and treatment may lead to improvement of symptoms, the signs return after a period of time. Causes of ARDS are different. It can be caused by direct or indirect damage to the lung epithelium. ARDS is described by severe hypoxemia, decreased pulmonary compliance, diffuse alveolar damage, and bilateral pulmonary infiltrates after cardiac edema [), ReferencedContent(href=None, text=1), Text(, ), ReferencedContent(href=None, text=2), Text(] and confirmed by a combination of clinical, physiological, and chest imaging parameters. Pulmonary inflammation with disruption of the mechanism of the alveolar–capillary barrier is an important direct cause of ARDS [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=4), Text(]. Therapeutic approaches include mechanical ventilation, neuromuscular blocking agents, fluid management, drug and antimicrobial therapy, and prone positioning [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=6), Text(]. These therapeutic strategies have a supportive role and cannot prevent the progression of the disease [), ReferencedContent(href=None, text=7), Text(–), ReferencedContent(href=None, text=10), Text(]. The ultimate approach is lung transplant, but it has many problems for recipient patients such as lack of suitable donors and the use of immunosuppressive drugs over a lifetime to prevent rejection of the transplant [), ReferencedContent(href=None, text=11), Text(]. Therefore, the recognition of new therapeutic approaches such as stromal cell therapy is essential [), ReferencedContent(href=None, text=12), Text(]. MSCs confer immunomodulatory and anti-inflammatory effects, enhance bacterial clearance, reduce cell injury and death, and are angiogenic [), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=13), Text(]. The mechanism of the MSCs’ effects includes several pathways mediated through differentiation, proliferation, soluble intermediate release, extracellular vesicles, transfer of organelles, and direct cell-to-cell contact, which decrease activation of inflammatory cell secretion of paracrine mediators [), ReferencedContent(href=None, text=14), Text(, ), ReferencedContent(href=None, text=15), Text(]. Recent studies have shown positive effects of MSC-based therapy for ARDS. Induction of inflammation by the LPS of ), Text(Escherichia coli), Text( O55:B5 is one of the best and simplest methods for making an experimental model of ARDS. Although the ARDS animal models cannot reflect human ARDS accurately, the rabbit model is similar and hence suitable for translating the results from pilot to clinical conditions [), ReferencedContent(href=None, text=16), Text(]. Anatomical, physiological, genetic, and biochemical similarity to humans simulates human lung disease, and as the rabbit is easy to handle, it is considered as a suitable model for pulmonary research [), ReferencedContent(href=None, text=17), Text(, ), ReferencedContent(href=None, text=18), Text(]. Moreover, the rabbit serves as an excellent platform for treatment based on stromal cells [), ReferencedContent(href=None, text=19), Text(, ), ReferencedContent(href=None, text=20), Text(]. Thus, in this study, the rabbit was used as a model for causing ARDS, and then it was treated with stromal cells. The aim of this study was evaluation of therapeutic potential intrapulmonary administration of BM-MSCs in an experimental model of ), Text(E. coli), Text( LPS-induced ARDS in the rabbit.))
#
# Section(title='Section', content=[Paragraph(i=3, Text(Lung disorders have significant morbidity and mortality rates worldwide, both in humans and in animals. Acute respiratory distress syndrome (ARDS) is one of the leading causes of respiratory failure around the world. Although early diagnosis, timely medical care, and treatment may lead to improvement of symptoms, the signs return after a period of time. Causes of ARDS are different. It can be caused by direct or indirect damage to the lung epithelium. ARDS is described by severe hypoxemia, decreased pulmonary compliance, diffuse alveolar damage, and bilateral pulmonary infiltrates after cardiac edema [), ReferencedContent(href=None, text=1), Text(, ), ReferencedContent(href=None, text=2), Text(] and confirmed by a combination of clinical, physiological, and chest imaging parameters. Pulmonary inflammation with disruption of the mechanism of the alveolar–capillary barrier is an important direct cause of ARDS [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=4), Text(]. Therapeutic approaches include mechanical ventilation, neuromuscular blocking agents, fluid management, drug and antimicrobial therapy, and prone positioning [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=6), Text(]. These therapeutic strategies have a supportive role and cannot prevent the progression of the disease [), ReferencedContent(href=None, text=7), Text(–), ReferencedContent(href=None, text=10), Text(]. The ultimate approach is lung transplant, but it has many problems for recipient patients such as lack of suitable donors and the use of immunosuppressive drugs over a lifetime to prevent rejection of the transplant [), ReferencedContent(href=None, text=11), Text(]. Therefore, the recognition of new therapeutic approaches such as stromal cell therapy is essential [), ReferencedContent(href=None, text=12), Text(]. MSCs confer immunomodulatory and anti-inflammatory effects, enhance bacterial clearance, reduce cell injury and death, and are angiogenic [), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=13), Text(]. The mechanism of the MSCs’ effects includes several pathways mediated through differentiation, proliferation, soluble intermediate release, extracellular vesicles, transfer of organelles, and direct cell-to-cell contact, which decrease activation of inflammatory cell secretion of paracrine mediators [), ReferencedContent(href=None, text=14), Text(, ), ReferencedContent(href=None, text=15), Text(]. Recent studies have shown positive effects of MSC-based therapy for ARDS. Induction of inflammation by the LPS of ), Text(Escherichia coli), Text( O55:B5 is one of the best and simplest methods for making an experimental model of ARDS. Although the ARDS animal models cannot reflect human ARDS accurately, the rabbit model is similar and hence suitable for translating the results from pilot to clinical conditions [), ReferencedContent(href=None, text=16), Text(]. Anatomical, physiological, genetic, and biochemical similarity to humans simulates human lung disease, and as the rabbit is easy to handle, it is considered as a suitable model for pulmonary research [), ReferencedContent(href=None, text=17), Text(, ), ReferencedContent(href=None, text=18), Text(]. Moreover, the rabbit serves as an excellent platform for treatment based on stromal cells [), ReferencedContent(href=None, text=19), Text(, ), ReferencedContent(href=None, text=20), Text(]. Thus, in this study, the rabbit was used as a model for causing ARDS, and then it was treated with stromal cells. The aim of this study was evaluation of therapeutic potential intrapulmonary administration of BM-MSCs in an experimental model of ), Text(E. coli), Text( LPS-induced ARDS in the rabbit.))])
# Paragraph(i=3, Text(Bone marrow (BM) samples were obtained from the humerus of rabbits in aseptic surgical conditions. After 30 min of centrifugation (400 relative centrifugal force), mononuclear cells were collected from the interphase, and eventually the cell pellets were seeded into 25-cm), Text(2), Text( flasks (SPL Life Sciences, Pocheon, South Korea) with DMEM-high glucose, 20% FBS (Life Technologies, Carlsbad, CA, USA), and 100 U/ml penicillin/streptomycin (Biowest, Nuaillé, France) and incubated at 37 °C in humid air with 5% CO), Text(2), Text( (Memmert, Eagle, WI, USA). When the adhesion of the cells was near confluence (more than 70%), the cells were trypsinized by trypsin-ethylenediaminetetraacetic acid of 0.25% (Life Technologies) and replated at dilutions of 1:2 under conditions of the same cultivation. The characteristics of the BM-MSCs were labeled with phycoerythrin-conjugated antibodies against CD45 (BioLegend, San Diego, CA, USA), CD90 (eBioscience, San Diego, CA, USA) and CD34 and CD29 (Abcam, Cambridge, UK), and the multilineage differentiation ability of BM-MSCs to engage in osteogenic and adipogenic differentiation was checked in vitro. This is described in more detail in the additional files.))
#
# Section(title='Isolation, primary culture, and expansion of BM-MSCs', content=[Paragraph(i=4, Text(Bone marrow (BM) samples were obtained from the humerus of rabbits in aseptic surgical conditions. After 30 min of centrifugation (400 relative centrifugal force), mononuclear cells were collected from the interphase, and eventually the cell pellets were seeded into 25-cm), Text(2), Text( flasks (SPL Life Sciences, Pocheon, South Korea) with DMEM-high glucose, 20% FBS (Life Technologies, Carlsbad, CA, USA), and 100 U/ml penicillin/streptomycin (Biowest, Nuaillé, France) and incubated at 37 °C in humid air with 5% CO), Text(2), Text( (Memmert, Eagle, WI, USA). When the adhesion of the cells was near confluence (more than 70%), the cells were trypsinized by trypsin-ethylenediaminetetraacetic acid of 0.25% (Life Technologies) and replated at dilutions of 1:2 under conditions of the same cultivation. The characteristics of the BM-MSCs were labeled with phycoerythrin-conjugated antibodies against CD45 (BioLegend, San Diego, CA, USA), CD90 (eBioscience, San Diego, CA, USA) and CD34 and CD29 (Abcam, Cambridge, UK), and the multilineage differentiation ability of BM-MSCs to engage in osteogenic and adipogenic differentiation was checked in vitro. This is described in more detail in the additional files.))])
# Paragraph(i=4, Text(Bone marrow (BM) samples were obtained from the humerus of rabbits in aseptic surgical conditions. After 30 min of centrifugation (400 relative centrifugal force), mononuclear cells were collected from the interphase, and eventually the cell pellets were seeded into 25-cm), Text(2), Text( flasks (SPL Life Sciences, Pocheon, South Korea) with DMEM-high glucose, 20% FBS (Life Technologies, Carlsbad, CA, USA), and 100 U/ml penicillin/streptomycin (Biowest, Nuaillé, France) and incubated at 37 °C in humid air with 5% CO), Text(2), Text( (Memmert, Eagle, WI, USA). When the adhesion of the cells was near confluence (more than 70%), the cells were trypsinized by trypsin-ethylenediaminetetraacetic acid of 0.25% (Life Technologies) and replated at dilutions of 1:2 under conditions of the same cultivation. The characteristics of the BM-MSCs were labeled with phycoerythrin-conjugated antibodies against CD45 (BioLegend, San Diego, CA, USA), CD90 (eBioscience, San Diego, CA, USA) and CD34 and CD29 (Abcam, Cambridge, UK), and the multilineage differentiation ability of BM-MSCs to engage in osteogenic and adipogenic differentiation was checked in vitro. This is described in more detail in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=5, Text(Bone marrow (BM) samples were obtained from the humerus of rabbits in aseptic surgical conditions. After 30 min of centrifugation (400 relative centrifugal force), mononuclear cells were collected from the interphase, and eventually the cell pellets were seeded into 25-cm), Text(2), Text( flasks (SPL Life Sciences, Pocheon, South Korea) with DMEM-high glucose, 20% FBS (Life Technologies, Carlsbad, CA, USA), and 100 U/ml penicillin/streptomycin (Biowest, Nuaillé, France) and incubated at 37 °C in humid air with 5% CO), Text(2), Text( (Memmert, Eagle, WI, USA). When the adhesion of the cells was near confluence (more than 70%), the cells were trypsinized by trypsin-ethylenediaminetetraacetic acid of 0.25% (Life Technologies) and replated at dilutions of 1:2 under conditions of the same cultivation. The characteristics of the BM-MSCs were labeled with phycoerythrin-conjugated antibodies against CD45 (BioLegend, San Diego, CA, USA), CD90 (eBioscience, San Diego, CA, USA) and CD34 and CD29 (Abcam, Cambridge, UK), and the multilineage differentiation ability of BM-MSCs to engage in osteogenic and adipogenic differentiation was checked in vitro. This is described in more detail in the additional files.))])
# Paragraph(i=5, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))
#
# Section(title='ARDS experimental model', content=[Paragraph(i=6, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))])
# Paragraph(i=6, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=7, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))])
# Paragraph(i=7, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))
#
# Section(title='BM-MSC autologous transplant', content=[Paragraph(i=8, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])
# Paragraph(i=8, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=9, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])
#
# Section(title='Experimental design', content=[
# Section(title='Section', content=[Paragraph(i=9, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))]),
# Section(title='Section', content=[Paragraph(i=9, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])])
# Paragraph(i=9, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=10, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))])
# Paragraph(i=10, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=11, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))])
# Paragraph(i=11, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=12, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])
# Paragraph(i=12, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=13, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])
#
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=13, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))]),
# Section(title='Section', content=[Paragraph(i=13, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])])
# Paragraph(i=13, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))
#
# Section(title='Clinical assessment', content=[Paragraph(i=14, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])
# Paragraph(i=14, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))
#
# Section(title='Section', content=[Paragraph(i=15, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])
#
# Section(title='Analyses', content=[
# Section(title='Section', content=[Paragraph(i=15, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])])
# Paragraph(i=15, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))
#
# Section(title='Section', content=[Paragraph(i=16, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])
# Paragraph(i=16, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))
#
# Section(title='Section', content=[Paragraph(i=17, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])
#
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=17, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])])
# Paragraph(i=17, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))
#
# Section(title='Computed tomography and echocardiography', content=[Paragraph(i=18, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])
# Paragraph(i=18, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=19, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])
#
# Section(title='Imaging', content=[
# Section(title='Section', content=[Paragraph(i=19, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])])
# Paragraph(i=19, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=20, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])
# Paragraph(i=20, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=21, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])
#
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=21, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])])
# Paragraph(i=21, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))
#
# Section(title='Blood and bronchoalveolar lavage samples', content=[Paragraph(i=22, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))])
# Paragraph(i=22, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=23, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))])
#
# Section(title='Sampling', content=[
# Section(title='Section', content=[Paragraph(i=23, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))])])
# Paragraph(i=23, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))
#
# Section(title='Section', content=[Paragraph(i=24, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))])
# Paragraph(i=24, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))
#
# ...
# Paragraph(i=233, Text(Our results displayed inflammatory cells downregulated by BM-MSCs, which can improve the function of the alveolar-capillary membrane, in agreement with the results of Xiang et al. on improving pulmonary microvascular permeability with MSCs [), ReferencedContent(href=None, text=32), Text(]. The reduction of heterophils, macrophages, and the number of total cells were observed in the treated group, unlike the results of other research [), ReferencedContent(href=None, text=26), Text(]. The complete blood count findings indicated that despite intrapulmonary administration of LPS and MSCs, there is a relationship between the numbers of intravascular and intra-alveolar heterophils and lymphocytes. Direct administration of LPS effects on gas exchange process and induces acute hypoxemia [), ReferencedContent(href=None, text=33), Text(]. The results of studies suggest that MSC transplant can improve hypoxemia via reducing alveolar-arterial oxygen gradient [), ReferencedContent(href=None, text=29), Text(, ), ReferencedContent(href=None, text=30), Text(] which is in agreement with the present study. But the research results of Moodley et al., (2016) conflicted with this study [), ReferencedContent(href=None, text=27), Text(]. The difference in injury model and type of cell therapy may be the cause of the variable results. There are not any studies that have reported clinical signs, including HR, RR, and RT, after stromal cell therapy; this study is the first report in which clinical signs were evaluated using a previously described scoring system.))
# Paragraph(i=234, Text(The protective effects of BM-MSCs on ARDS are a result of the immune regulation function and inhibitory T-cell function [), ReferencedContent(href=None, text=31), Text(]. Monocytes and macrophages can release inflammatory factors such as TNF-α that play a role in phagocytes of the necrotic and apoptotic cells [), ReferencedContent(href=None, text=34), Text(]. Because MSC soluble factors may be the therapeutic basis of MSCs, this result is confirmed by recent reports that demonstrated immunomodulatory properties of MSCs [), ReferencedContent(href=None, text=26), Text(]. MSCs’ effects are explained by a shift from a proinflammatory to an anti-inflammatory response [), ReferencedContent(href=None, text=26), Text(]. Reduced cytokines of proinflammatory (TNF-α and IL-6) and increased cytokines of anti-inflammatory (IL-10) in BAL and plasma samples play principal roles in the treatment mechanism of ARDS [), ReferencedContent(href=None, text=26), Text(, ), ReferencedContent(href=None, text=29), Text(, ), ReferencedContent(href=None, text=30), Text(]. In the present study, the TNF-α concentration decreased following MSC therapy, which is similar to many studies [), ReferencedContent(href=None, text=31), Text(]. The IL-10 level increased after the use of MSCs and inhibited antigen-presenting cell function and inflammation and enhanced tolerance, but our findings are not similar to some other studies [), ReferencedContent(href=None, text=26), Text(, ), ReferencedContent(href=None, text=30), Text(]. Beneficial effects of MSCs may be mediated by a decrease of TNF that indicated the attenuation of the inflammation [), ReferencedContent(href=None, text=26), Text(]. Prostaglandin E2 (PGE2) has a critical role in IL-10 and IL-6 secretion from macrophages [), ReferencedContent(href=None, text=31), Text(]. It is possible that TNF- and IL-6-dependent PGE2 production plays a major role as a clinical sign and in particular hyperthermia in the acute phase of inflammation [), ReferencedContent(href=None, text=34), Text(]. TNF has roles in local inflammation complications such as leukocyte stimulation (neutrophils and macrophage) in BAL and lung endothelium that was shown in the pathology. Also, TNF has roles in systemic complications such as hyperthermia, C-reactive protein, leukocytosis, necrosis, and apoptosis, decreasing appetite, and even decreases of cardiac output and vascular permeability and increases in edema and hypotension.))
# Paragraph(i=235, Text(In this study, CT scans and echocardiography were used to follow improvement and management of ARDS during BM-MSC therapy. One particular feature of ARDS is lack of aerated lung volume caused by inflammation and edema, and total lung volume reduction (air + parenchyma) mostly in the lower lobes can explain hypoxemia, low respiratory compliance, and alveolar dead space and increased pulmonary vascular permeability [), ReferencedContent(href=None, text=35), Text(, ), ReferencedContent(href=None, text=36), Text(]. CT scanning is a common clinical diagnostic tool, a specific, repeatable, and noninvasive technique for diagnosis that until now has rarely been used as a research tool, and there is not any valid data of the distribution region of the existence or absence of air in alveolus during ARDS and especially after cell-based therapy. Our findings based on CT scanning are matched with the diagnosis of pathology and all the other outcomes. Therefore, it can be said that CT scanning is a suitable method for evaluation of the stromal cell therapy effects in pulmonary inflammation and edema, but further studies are needed in this field. Interactions between lung, right ventricle, and pulmonary circulation are critical in ARDS. Serial echocardiographic measurements have a potential clinical diagnosis in the early stage ARDS as a prognostic and therapeutic method. We showed that ARDS causes changes in echocardiographic parameters and reduces cardiac function, whereas transplant of BM-MSCs was able to prevent these changes.))
# Paragraph(i=236, Text(We demonstrated that MSCs could attenuate the inflammation by reducing pathological lung changes [), ReferencedContent(href=None, text=31), Text(], but in some research, no significant data were reported regarding pathology. This variation may be caused by short study duration so that further studies are needed. Our histopathological examination, like other findings from imaging and all of the laboratory results, showed that BM-MSC transplant could improve ARDS.))
#
# Section(title='Section', content=[Paragraph(i=237, Text(BM-MSCs are an ideal choice for cell therapy because there are fewer complications for cell isolation and also BM autologous cells that are capable of eliminating immune response and transplant rejection [), ReferencedContent(href=None, text=22), Text(]. MSCs have positive effects in the repair of ARDS [), ReferencedContent(href=None, text=23), Text(].)), Paragraph(i=237, Text(Although fibroblasts play a role in normal and pathological repair, and an accumulation of fibrocytes, fibroblasts, and myofibroblasts in the alveolar compartment, leading to excessive deposition components of the extracellular matrix but also according to prior findings the effect of them remains controversial [), ReferencedContent(href=None, text=23), Text(–), ReferencedContent(href=None, text=25), Text(] and unknown, so that reduction of its deposition or enhancement of its degradation could be treatment strategies. [), ReferencedContent(href=None, text=24), Text(])), Paragraph(i=237, Text(The results of this study showed that the BM-MSCs significantly decreased the severity of clinical symptoms induced by LPS, the number of inflammatory cells in blood and BAL, and balanced the values of arterial blood gases and cytokines. On the CT scans, a significant decrease in the Hounsfield units was observed, which is indicative of an increase in aerated volume of the lung in the treatment group. The echocardiographic parameters did not reveal a significant difference in the treatment group, and compared with the two groups together it was significant. Also, the histopathology demonstrated reduction in the infiltration of inflammatory cells and pulmonary hemorrhage and edema in the recipients of BM-MSCs.)), Paragraph(i=237, Text(In natural conditions, cells from bone marrow migrated to chemotactic gradients, but the amount of engraftment was low, and use of exogenous stromal cells can be helpful to this mechanism. The exact mechanisms of MSCs’ actions are not precise [), ReferencedContent(href=None, text=25), Text(], and sometimes the results of stromal cell research using animal models are incompatible with each other [), ReferencedContent(href=None, text=23), Text(]. However, three mechanisms have been defined for MSCs’ actions consisting of differentiation, cell–cell contact and paracrine function via the soluble factors [), ReferencedContent(href=None, text=25), Text(, ), ReferencedContent(href=None, text=26), Text(]. Researchers are likely to focus on manipulation of inflammatory pathways and optimizing lung repair while preventing ARDS progression [), ReferencedContent(href=None, text=6), Text(]; whereas management of inflammatory pathways forbids the development of ARDS, some researchers believe in the immunomodulatory effects of MSCs [), ReferencedContent(href=None, text=6), Text(]. Most trials have used local delivery of autologous BM-MSCs with the aim increasing the concentration of growth factors and cytokines in damaged tissue to improve possible engraftment and repair [), ReferencedContent(href=None, text=23), Text(]. For the first time, Gupta et al. reported effects of the local delivery of MSCs in ARDS that are consistent with this study [), ReferencedContent(href=None, text=26), Text(].)), Paragraph(i=237, Text(The anti-inflammatory role of MSCs may vary in humans and animals, but the useful effects of MSCs have been shown in several animal models [), ReferencedContent(href=None, text=27), Text(] and indicate the significant role of identification feature of MSCs [), ReferencedContent(href=None, text=22), Text(]. LPS of gram-negative bacterial wall binds to the CD14/TLR4/MD2 receptor complex, activating pathway and transcription of some inflammation- and apoptosis-related genes and activating innate immune response [), ReferencedContent(href=None, text=18), Text(, ), ReferencedContent(href=None, text=25), Text(] that produces the acute phase of ARDS. Therefore, the LPS-induced animal models ...
# Paragraph(i=237, Text(Many studies on cell-based therapies in ARDS have been done, but most of them focused on molecular and signal tests. Although these studies could clear pathways, they are still far from tissue function. In this study, we tried to explain the MSCs’ effects on organ function. We investigated effects of BM-MSCs in an experimental model of ARDS and confirmed that MSCs decrease inflammation and improve alveolar fluid clearance and have a protective role in ARDS. Improvement in clinical signs, the decrease of inflammatory cells in blood and BAL, the balance in blood gases and cytokines, the decrease in the Hounsfield units, no changes in echocardiographic parameters. and the reduction of pulmonary hemorrhage and edema in pathology were observed. Despite these results, subsequent studies are required to confirm the decrease in inflammation, and physiological parameters over the long term and many experiments should be performed until stromal cell therapy is validated as a method of routine clinical treatment.))
#
# Section(title='Conclusions', content=[Paragraph(i=238, Text(Many studies on cell-based therapies in ARDS have been done, but most of them focused on molecular and signal tests. Although these studies could clear pathways, they are still far from tissue function. In this study, we tried to explain the MSCs’ effects on organ function. We investigated effects of BM-MSCs in an experimental model of ARDS and confirmed that MSCs decrease inflammation and improve alveolar fluid clearance and have a protective role in ARDS. Improvement in clinical signs, the decrease of inflammatory cells in blood and BAL, the balance in blood gases and cytokines, the decrease in the Hounsfield units, no changes in echocardiographic parameters. and the reduction of pulmonary hemorrhage and edema in pathology were observed. Despite these results, subsequent studies are required to confirm the decrease in inflammation, and physiological parameters over the long term and many experiments should be performed until stromal cell therapy is validated as a method of routine clinical treatment.))])
# Paragraph(i=238, Text(Many studies on cell-based therapies in ARDS have been done, but most of them focused on molecular and signal tests. Although these studies could clear pathways, they are still far from tissue function. In this study, we tried to explain the MSCs’ effects on organ function. We investigated effects of BM-MSCs in an experimental model of ARDS and confirmed that MSCs decrease inflammation and improve alveolar fluid clearance and have a protective role in ARDS. Improvement in clinical signs, the decrease of inflammatory cells in blood and BAL, the balance in blood gases and cytokines, the decrease in the Hounsfield units, no changes in echocardiographic parameters. and the reduction of pulmonary hemorrhage and edema in pathology were observed. Despite these results, subsequent studies are required to confirm the decrease in inflammation, and physiological parameters over the long term and many experiments should be performed until stromal cell therapy is validated as a method of routine clinical treatment.))
#
# Section(title='Section', content=[Paragraph(i=239, Text(Many studies on cell-based therapies in ARDS have been done, but most of them focused on molecular and signal tests. Although these studies could clear pathways, they are still far from tissue function. In this study, we tried to explain the MSCs’ effects on organ function. We investigated effects of BM-MSCs in an experimental model of ARDS and confirmed that MSCs decrease inflammation and improve alveolar fluid clearance and have a protective role in ARDS. Improvement in clinical signs, the decrease of inflammatory cells in blood and BAL, the balance in blood gases and cytokines, the decrease in the Hounsfield units, no changes in echocardiographic parameters. and the reduction of pulmonary hemorrhage and edema in pathology were observed. Despite these results, subsequent studies are required to confirm the decrease in inflammation, and physiological parameters over the long term and many experiments should be performed until stromal cell therapy is validated as a method of routine clinical treatment.))])
# NestedContainer(ReferencedContent(href=None, text=))
# Paragraph(i=239, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))
#
# Section(title='Section', content=[Paragraph(i=240, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])
# NestedContainer(ReferencedContent(href=None, text=))
# Paragraph(i=240, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))
#
# Section(title='Section', content=[Paragraph(i=241, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])
#
# Section(title='Additional file', content=[
# Section(title='Section', content=[Paragraph(i=241, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])])
# NestedContainer(ReferencedContent(href=None, text=))
# Paragraph(i=241, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))
#
# Section(title='Section', content=[Paragraph(i=242, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])
# NestedContainer(ReferencedContent(href=None, text=))
# Paragraph(i=242, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))
#
# Section(title='Section', content=[Paragraph(i=243, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])
#
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])])

# %%
article.get_body_structure()
# Out:
# [
# Section(title='Section', content=[Paragraph(i=243, Text(Lung disorders have significant morbidity and mortality rates worldwide, both in humans and in animals. Acute respiratory distress syndrome (ARDS) is one of the leading causes of respiratory failure around the world. Although early diagnosis, timely medical care, and treatment may lead to improvement of symptoms, the signs return after a period of time. Causes of ARDS are different. It can be caused by direct or indirect damage to the lung epithelium. ARDS is described by severe hypoxemia, decreased pulmonary compliance, diffuse alveolar damage, and bilateral pulmonary infiltrates after cardiac edema [), ReferencedContent(href=None, text=1), Text(, ), ReferencedContent(href=None, text=2), Text(] and confirmed by a combination of clinical, physiological, and chest imaging parameters. Pulmonary inflammation with disruption of the mechanism of the alveolar–capillary barrier is an important direct cause of ARDS [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=4), Text(]. Therapeutic approaches include mechanical ventilation, neuromuscular blocking agents, fluid management, drug and antimicrobial therapy, and prone positioning [), ReferencedContent(href=None, text=3), Text(, ), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=6), Text(]. These therapeutic strategies have a supportive role and cannot prevent the progression of the disease [), ReferencedContent(href=None, text=7), Text(–), ReferencedContent(href=None, text=10), Text(]. The ultimate approach is lung transplant, but it has many problems for recipient patients such as lack of suitable donors and the use of immunosuppressive drugs over a lifetime to prevent rejection of the transplant [), ReferencedContent(href=None, text=11), Text(]. Therefore, the recognition of new therapeutic approaches such as stromal cell therapy is essential [), ReferencedContent(href=None, text=12), Text(]. MSCs confer immunomodulatory and anti-inflammatory effects, enhance bacterial clearance, reduce cell injury and death, and are angiogenic [), ReferencedContent(href=None, text=5), Text(, ), ReferencedContent(href=None, text=13), Text(]. The mechanism of the MSCs’ effects includes several pathways mediated through differentiation, proliferation, soluble intermediate release, extracellular vesicles, transfer of organelles, and direct cell-to-cell contact, which decrease activation of inflammatory cell secretion of paracrine mediators [), ReferencedContent(href=None, text=14), Text(, ), ReferencedContent(href=None, text=15), Text(]. Recent studies have shown positive effects of MSC-based therapy for ARDS. Induction of inflammation by the LPS of ), Text(Escherichia coli), Text( O55:B5 is one of the best and simplest methods for making an experimental model of ARDS. Although the ARDS animal models cannot reflect human ARDS accurately, the rabbit model is similar and hence suitable for translating the results from pilot to clinical conditions [), ReferencedContent(href=None, text=16), Text(]. Anatomical, physiological, genetic, and biochemical similarity to humans simulates human lung disease, and as the rabbit is easy to handle, it is considered as a suitable model for pulmonary research [), ReferencedContent(href=None, text=17), Text(, ), ReferencedContent(href=None, text=18), Text(]. Moreover, the rabbit serves as an excellent platform for treatment based on stromal cells [), ReferencedContent(href=None, text=19), Text(, ), ReferencedContent(href=None, text=20), Text(]. Thus, in this study, the rabbit was used as a model for causing ARDS, and then it was treated with stromal cells. The aim of this study was evaluation of therapeutic potential intrapulmonary administration of BM-MSCs in an experimental model of ), Text(E. coli), Text( LPS-induced ARDS in the rabbit.))]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(Bone marrow (BM) samples were obtained from the humerus of rabbits in aseptic surgical conditions. After 30 min of centrifugation (400 relative centrifugal force), mononuclear cells were collected from the interphase, and eventually the cell pellets were seeded into 25-cm), Text(2), Text( flasks (SPL Life Sciences, Pocheon, South Korea) with DMEM-high glucose, 20% FBS (Life Technologies, Carlsbad, CA, USA), and 100 U/ml penicillin/streptomycin (Biowest, Nuaillé, France) and incubated at 37 °C in humid air with 5% CO), Text(2), Text( (Memmert, Eagle, WI, USA). When the adhesion of the cells was near confluence (more than 70%), the cells were trypsinized by trypsin-ethylenediaminetetraacetic acid of 0.25% (Life Technologies) and replated at dilutions of 1:2 under conditions of the same cultivation. The characteristics of the BM-MSCs were labeled with phycoerythrin-conjugated antibodies against CD45 (BioLegend, San Diego, CA, USA), CD90 (eBioscience, San Diego, CA, USA) and CD34 and CD29 (Abcam, Cambridge, UK), and the multilineage differentiation ability of BM-MSCs to engage in osteogenic and adipogenic differentiation was checked in vitro. This is described in more detail in the additional files.))]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(Ten healthy adult male New Zealand white rabbits were chosen, and an ARDS experimental model was induced with LPS from ), Text(E. coli), Text( O55:B5 [), ReferencedContent(href=None, text=21), Text(] (Sigma-Aldrich, St. Louis, MO, USA) at 400 μg/kg dissolved in 0.1 ml of PBS intrapulmonary the under bronchoscopic guidance. After the ARDS confirmation, rabbits were randomly distributed into two groups: (1) the control group (ARDS + PBS) and (2) the treatment group (ARDS + BM-MSC). Protocol details are available in the additional files.))]),
# Section(title='Section', content=[Paragraph(i=243, Text(A total of 10), Text(10), Text( BM-MSCs suspended in 0.1 ml of PBS [), ReferencedContent(href=None, text=5), Text(] were autologously transplanted intrapulmonary under bronchoscopic guidance 24 h after induction of ARDS. Details of the method are provided in the additional files.))])]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(During the study, the clinical signs of rabbits were calculated and recorded on the basis of clinical scores for each rabbit. Heart rate (HR), respiratory rate (RR), body temperature, twitch, abnormal breathing, nasal discharge, cough, appetite, and physical condition were measured using a clinical score. The scoring is based on clinically evaluated criteria that were individually defined and measured for each rabbit (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S1).))])]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(Computed tomographic (CT) scans of the lung of rabbits were taken with the SOMATOM Spirit Class II (Siemens, Erlangen, Germany), and echocardiographic examinations were performed using a Vivid 7 ultrasound system (GE Healthcare, Milwaukee, WI, USA) with a 4.4–10.0-MHz phased-array transducer (10S) during experimental modeling of ARDS before and 12, 24, 48, 72, and 168 h after transplant in each animal under the same circumstances. More details are provided in the additional files.))])]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(Blood samples were collected from the central ear artery for blood gas analyses using blood gas analyzers (OPTI CCA-TS; OPTI Medical Systems, Roswell, GA, USA) and from the ear vein for hematologic parameter analysis and measurement of cytokines (tumor necrosis factor [TNF]-α, interleukin [IL]-6, and IL-10) with a commercially available enzyme-linked immunosorbent assay kit (EASTBIOPHARM, Hangzhou, China) before transplant of BM-MSCs and then for 3, 6, 12, 24, 48, 72, and 168 h after transplant. Also, bronchoalveolar lavage (BAL) samples were collected by fiberoptic bronchoscope (11262 BC; Karl Storz, Tuttlingen, Germany) before and 24, 48, 72, and 168 h after transplant. Then, the centrifuged BALs were stored at − 80 °C for measurement of cytokines. Protocol details are available in the additional files.))])]),
# Section(title='Section', content=[Paragraph(i=243, Text(The rabbits were killed 7 days after BM-MSC transplant. First, the lungs and hearts were macroscopically examined, and then sections of them were routinely prepared, stained with H&E, and observed by use of an E600 Eclipse optical microscope (Nikon Instrument, Tokyo, Japan). More details are provided in the additional files.))]),
# Section(title='Section', content=[Paragraph(i=243, Text(The results were analyzed statistically using IBM SPSS Statistics version 24 software (IBM, Armonk, NY, USA). For variables in this study, data were analyzed with the repeated measures independent samples ), Text(t), Text( test, Friedman test, and Mann-Whitney ), Text(U), Text( test, and ), Text(p), Text( < 0.05 was considered statistically significant.))])]),
# Section(title='Section', content=[
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(The plastic adherent BM-MSCs proliferated 5–7 days after seeding and reached 80% confluence about 2 weeks later. After three passages, the adherent cells were observed by microscopy to display homogeneous spindle fibroblast-like morphology (Additional file ), ReferencedContent(href=None, text=1), Text(: Figure S1).))]),
# Section(title='Section', content=[Paragraph(i=243, Text(Flow cytometric analysis demonstrated that cultured BM-MSCs expressed a particular pattern of cell surface markers of CD29 and CD90, 92% and 89%, respectively, but were uniformly negative for CD34 and CD45 (Additional file ), ReferencedContent(href=None, text=1), Text(: Figure S2), which indicates cultured adherent cells were MSCs with high purity. Thus, the pure MSCs whose immunophenotype was confirmed were used in this study.))]),
# Section(title='Section', content=[Paragraph(i=243, Text(Multilineage differentiation ability of BM-MSCs to engage in osteogenic and adipogenic differentiation in vitro confirmed potential pluripotent MSCs, and their ability to form osteoblasts and adipocytes when incubated in differentiation medium was retained (Additional file ), ReferencedContent(href=None, text=1), Text(: Figure S3).))])]),
# Section(title='Section', content=[Paragraph(i=243, Text(Twenty-four hours after the intrapulmonary administration of LPS, inflammation and edema were stabilized in the lung. Two different evaluations proved ARDS occurrence: (1) Clinical examination showed changes in respiratory sounds during auscultation, such as crackle and wheeze, increased respiratory rate/hyperpnea (), Text(p), Text( = 0.004), heart rate/tachycardia (), Text(p), Text( = 0.008) and body temperature/hyperthermia (), Text(p), Text( = 0.011), cough, mucus hyperemia, abnormal discharge, and reduced appetite; and (2) plain chest radiograph showing significant bilateral radiologic density (air bronchogram and air alveologram patterns and lung edema and bronchial and bronchiolar septum thickness) were also confirmed (Additional file ), ReferencedContent(href=None, text=1), Text(: Figure S4). These results confirmed the experimental model of ARDS compared with the baseline 24 h after injection of LPS.))]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(According to the statistical analysis, reduction of RR in the treatment group was significant at 24 h (), Text(p), Text( = 0.002), 48 h (), Text(p), Text( = 0.036), 72 h (), Text(p), Text( = 0.037), and 168 h (), Text(p), Text( = 0.042) after BM-MSC transplant compared with time 0 (before BM-MSC transplant). HR reduction was significant at 24 h (), Text(p), Text( = 0.047) after transplant compared with time 0, but in RR and HR in the control group, it was not significantly different at various times. The RR results of the comparison between two groups showed a significant difference at 24 h (), Text(p), Text( = 0.028), 48 h (), Text(p), Text( = 0.03), 72 h (), Text(p), Text( = 0.01), and 168 h (), Text(p), Text( = 0.044) (Fig. ), ReferencedContent(href=None, text=1), Text( and Additional file ), ReferencedContent(href=None, text=1), Text(: Table S2). The body temperature change in rabbits of the treatment group was significant at 6 h (), Text(p), Text( = 0.010), 12 h (), Text(p), Text( = 0.016), 24 h (), Text(p), Text( = 0.044), 72 h (), Text(p), Text( = 0.044), and 168 h(), Text(p), Text( = 0.043) after transplant compared with time 0. Also, the comparison between two groups showed significant differences at 12 h (), Text(p), Text( = 0.047), 24 h (), Text(p), Text( = 0.021), 48 h (), Text(p), Text( = 0.035), and 168 h (), Text(p), Text( = 0.037) (Fig. ), ReferencedContent(href=None, text=1), Text( and Additional file ), ReferencedContent(href=None, text=1), Text(: Table S2).), Figure(label=None, caption=None, text=)), Paragraph(i=243, Text(Changes in respiratory sounds (including crackle, wheeze, friction sounds) in the treatment group were significant compared with the control group at 24 h (), Text(p), Text( = 0.50), 48 h (), Text(p), Text( = 0.014), 72 h (), Text(p), Text( = 0.017), and 168 h (), Text(p), Text( = 0.014) after transplant. Comparison of appetite between the two groups displayed a positive and significant association at 12 h (), Text(p), Text( = 0.002), 24 h (), Text(p), Text( = 0.014), 48 h (), Text(p), Text( = 0.007), 72 h (), Text(p), Text( = 0.004), and 168 h (), Text(p), Text( = 0.004) after transplant.)), Paragraph(i=243, Text(In both groups, after inflammation, unilateral or bilateral mucosal secretions from the nose were produced that were occasionally accompanied by color changes. But after transplant of BM-MSCs, statistical comparison showed a significant decrease in nasal discharge compared with the control group at 24 h (), Text(p), Text( = 0.011), 48 h (), Text(p), Text( = 0.007), 72 h (), Text(p), Text( = 0.007), and 168 h (), Text(p), Text( = 0.008). The regular rhythm of nasal twitching in the rabbit is a reason for the rabbit’s health and alertness. Nasal twitching was reduced at the time of inflammation. But there was a significant difference between results at 12 h (), Text(p), Text( = 0.005), 24 h (), Text(p), Text( = 0.005), 72 h (), Text(p), Text( = 0.014), and 168 h (), Text(p), Text( = 0.014) after transplant.)), Paragraph(i=243, Text(Also, there was a significant decrease in cough count between the two groups at 12 h (), Text(p), Text( = 0.014), 24 h (), Text(p), Text( = 0.005), 48 h (), Text(p), Text( = 0.006), 72 h (), Text(p), Text( = 0.004), and 168 h (), Text(p), Text( = 0.005). Regarding the statistical analysis, comparison of mucous membranes (conjunctiva, palpebra tertia, gingiva, rectum) in both groups showed hyperemia reduced at 24 h (), Text(p), Text( = 0.031), 48 h (), Text(p), Text( = 0.011), 72 h (), Text(p), Text( = 0.005), and 168 h (), Text(p), Text( = 0.005) after BM-MSC transplant. After inflammation, rabbits showed depression and delay in response to environmental stimuli. But transplant of BM-MSCs indicated a significant improvement in consciousness at 24 h (), Text(p), Text( = 0.017), 48 h (), Text(p), Text( = 0.017), 72 h (), Text(p), Text( = 0.004), and 168 h (), Text(p), Text( = 0.005).))])]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(The measured blood parameters at different times are shown in the Table ), ReferencedContent(href=None, text=1), Text(. Rabbits in the two groups had significant leukocytosis 1 day after inflammation (), Text(p), Text( < 0.005). But the BM-MSC transplant reduced the number of white blood cells. The changes were significant at 12 h (), Text(p), Text( = 0.046), 24 h (), Text(p), Text( = 0.019), 48 h (), Text(p), Text( = 0.022), 72 h (), Text(p), Text( = 0.044), and 168 h (), Text(p), Text( = 0.043) compared with time 0. Also, comparison of the two groups showed that cell transplant was effective at 6 h (), Text(p), Text( = 0.043), 12 h (), Text(p), Text( = 0.000), and 24 h (), Text(p), Text( = 0.047) (Table ), ReferencedContent(href=None, text=1), Text().), TableWrap(title=TableWrap, caption=None content=[Table(shape=(19, 11))])), Paragraph(i=243, Text(The transplant of BM-MSCs reduced the heterophil count following ARDS. Changes were significant at 12 h (), Text(p), Text( = 0.048), 24 h (), Text(p), Text( = 0.049), 48 h (), Text(p), Text( = 0.009), 72 h (), Text(p), Text( = 0.007), and 168 h (), Text(p), Text( = 0.024) against inflammation time (time 0). The comparison between two groups showed significant differences at 3 h (), Text(p), Text( = 0.020), 6 h (), Text(p), Text( = 0.042), 12 h (), Text(p), Text( = 0.030), 24 h (), Text(p), Text( = 0.001), and 48 h (), Text(p), Text( = 0.046) (Additional file ), ReferencedContent(href=None, text=1), Text(: Figure S5).)), Paragraph(i=243, Text(Comparison of heterophil band numbers between the two groups showed that cell transplant was affected at 48 h (), Text(p), Text( = 0.046), 72 h (), Text(p), Text( = 0.021), and 168 h (), Text(p), Text( = 0.038).)), Paragraph(i=243, Text(Statistical analysis showed that there was no significant difference in the lymphocyte count, monocytes, platelets, hematocrit in or between the treatment and control groups during the study. There was a significant difference in the number of red blood cells (), Text(p), Text( = 0.007) and concentration of hemoglobin (), Text(p), Text( = 0.027) in the treatment group compared with the control group only at 48 h.))]),
# Section(title='Section', content=[Paragraph(i=243, Text(In BAL, the total nucleated cell count included ciliated epithelial cells, squamous epithelial cells, alveolar macrophages, leukocytes, heterophils, eosinophils, and plasma cells. Typically, total leukocyte cells in treatment group included macrophages and lymphocytes, and in the control group, they included macrophages and heterophils (Fig. ), ReferencedContent(href=None, text=2), Text().), Figure(label=None, caption=None, text=)), Paragraph(i=243, Text(The results demonstrated that the BAL cell count was significantly increased in inflammatory conditions, but transplant of stromal cells caused the inflammatory cells to balance so that, in the treatment group, decrease of the total cell count was significant at all times except time 0 (), Text(p), Text( < 0.05), and there was a significant reduction in the total cell count compared with the control group at 24 h (), Text(p), Text( = 0.045), 48 h (), Text(p), Text( = 0.46), and 72 h (), Text(p), Text( = 0.048). Also, BM-MSCs were able to significantly reduce the number of alveolar heterotrophs, as well as the number of macrophages in BAL, so that decrease of heterotrophs was significant at 12 h (), Text(p), Text( = 0.03), 24 h (), Text(p), Text( = 0.01), 48 h, 72 h, and 168 h (), Text(p), Text( = 0.000) against inflammation time and at 48 h (), Text(p), Text( = 0.049), 72 h (), Text(p), Text( = 0.031), and 168 h (), Text(p), Text( = 0.042) compared with the control group. Also, reduction in macrophages was significant at 72 h (), Text(p), Text( = 0.033) and 168 h (), Text(p), Text( = 0.005) compared with time 0. No significant change in the number of lymphocytes was observed in or between the two groups (Fig. ), ReferencedContent(href=None, text=3), Text() (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S3).), Figure(label=None, caption=None, text=))])]),
# Section(title='Section', content=[Paragraph(i=243, Text(The partial pressure of oxygen (PO), Text(2), Text() and O), Text(2), Text( saturation (SatO), Text(2), Text() levels were decreased, and partial pressure of carbon dioxide (PCO), Text(2), Text() levels were increased, in ARDS (time 0) compared with baseline (− 24 h), significantly. Following BM-MSC transplant, PO), Text(2), Text( increment was significant at 12 h (), Text(p), Text( = 0.043), 24 h (), Text(p), Text( = 0.005), and 48 h (), Text(p), Text( = 0.005), and comparison between the two groups demonstrated that severe hypoxemia was significantly recovered after transplant at 12 h (), Text(p), Text( = 0.027), 24 h (), Text(p), Text( = 0.042), and 48 h (), Text(p), Text( = 0.040).)), Paragraph(i=243, Text(Also, following transplant of BM-MSCs, changes of SatO), Text(2), Text( were significant at 12 h (), Text(p), Text( = 0.038), 24 h (), Text(p), Text( = 0.030), 48 h (), Text(p), Text( = 0.009), 72 h (), Text(p), Text( = 0.007), and 168 h (), Text(p), Text( = 0.024) compared with time 0, and comparison of the two groups showed that cell transplant was effective at 3 h (), Text(p), Text( = 0.020), 6 h (), Text(p), Text( = 0.042), 12 h (), Text(p), Text( = 0.030), 24 h (), Text(p), Text( = 0.001), and 48 h (), Text(p), Text( = 0.046) (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S4).)), Paragraph(i=243, Text(Additionally, PCO), Text(2), Text( was significantly decreased in the treatment group at 24 h (), Text(p), Text( = 0.036), 48 h (), Text(p), Text( = 0.034), and 72 h (), Text(p), Text( = 0.01) after transplant, and comparison between the two groups displayed a significant decrease of PCO), Text(2), Text( at 48 h and 72 h (), Text(p), Text( = 0.016).)), Paragraph(i=243, Text(Also, statistical analysis for pH value indicated significant differences between the two groups at 24 h (), Text(p), Text( = 0.019). Respiratory acidosis occurred in both groups at 3 and 6 h via pH decrease and increase in PCO), Text(2), Text(. Analysis of bicarbonate, base excess, and anion gap data showed no significant difference in and between the two groups (Fig. ), ReferencedContent(href=None, text=4), Text().), Figure(label=None, caption=None, text=))]),
# Section(title='Section', content=[Paragraph(i=243, Text(The results showed nonsignificant reduction in the value of Na), Text(+), Text(, K), Text(+), Text(, and Cl), Text(−), Text( in and between the treatment and control groups at the different times and alone. There was a significant difference in the Cl), Text(−), Text( value in the treatment group compared with the control group at 24 h (), Text(p), Text( = 0.029) (Additional file ), ReferencedContent(href=None, text=1), Text(: Table S5).))]),
# Section(title='Section', content=[Paragraph(i=243, Text(Duplicated measurements of each variable were performed, and the average of the data was obtained. The measured cytokine levels in plasma and BAL samples at different times are shown in Additional file ), ReferencedContent(href=None, text=1), Text(: Table S6. BM-MSC transplant decreased proinflammatory cytokines (TNF-α and IL-6) and increased anticytokine inflammation (IL-10) during endotoxin injury in plasma and BAL.)), Paragraph(i=243, Text(After transplant of MSCs, the concentration of the TNF-α in BAL decreased at 12 h (), Text(p), Text( = 0.035), 24 h (), Text(p), Text( = 0.011), 48 h (), Text(p), Text( = 0.007), and 168 h (), Text(p), Text( = 0.014) compared with time 0, significantly, and comparison of the two groups showed that cell transplant was affected at times of 12 h (), Text(p), Text( = 0.031), 24 h (), Text(p), Text( = 0.018), 48 h (), Text(p), Text( = 0.009), and 168 h (), Text(p), Text( = 0.014). Also, the levels of TNF-α in plasma were recovered with MSCs at 24 h (), Text(p), Text( = 0.040), 48 h (), Text(p), Text( = 0.006), 72 h (), Text(p), Text( = 0.002), and 168 h (), Text(p), Text( = 0.003) against inflammation time (0 h), significantly, and comparison of the two groups showed significant difference at 72 h (), Text(p), Text( = 0.008) and 168 h (), Text(p), Text( = 0.025).)), Paragraph(i=243, Text(The IL-6 concentration was downregulated by MSCs, so that the levels of IL-6 in the BAL were significantly lower at times of 12 h (), Text(p), Text( = 0.047), 24 h (), Text(p), Text( = 0.011), 48 h (), Text(p), Text( = 0.001), and 168 h (), Text(p), Text( = 0.041) than time 0. Comparison of the two groups indicated significant differences at 12 h (), Text(p), Text( = 0.032), 24 h (), Text(p), Text( = 0.018), 72 h (), Text(p), Text( = 0.041), and 168 h (), Text(p), Text( = 0.008). Also, the concentration of IL-6 was significant in plasma 48 h (), Text(p), Text( = 0.048) and 168 h (), Text(p), Text( = 0.001) after MSC transplant against the inflammation time (0 h), and comparison of the two groups showed that cell therapy was affected at 24 h (), Text(p), Text( = 0.001), 48 h (), Text(p), Text( = 0.005), and 168 h (), Text(p), Text( = 0.012). These results demonstrated the immunomodulatory potential of these BM-MSCs.)), Paragraph(i=243, Text(In contrast, when MSCs were administered, IL-10 was significantly increased in the BAL and plasma. Concentration of IL-10 in BAL was significant at 12 h (), Text(p), Text( = 0.047), 24 h (), Text(p), Text( = 0.011), 48 h (), Text(p), Text( = 0.001), and 168 h (), Text(p), Text( = 0.041) compared with time 0, and comparison of the two groups showed significant differences at 12 h (), Text(p), Text( = 0.032), 24 h (), Text(p), Text( = 0.018), 72 h (), Text(p), Text( = 0.041), and 168 h (), Text(p), Text( = 0.008) (Fig. ), ReferencedContent(href=None, text=5), Text(). Also, increase of IL-10 concentration in plasma was significant at 48 h (), Text(p), Text( = 0.047), 72 h (), Text(p), Text( = 0.044), and 168 h (), Text(p), Text( = 0.022) against time 0. MSCs also increased plasma IL-10 concentrations compared with control group at 48 h (), Text(p), Text( = 0.043) and 72 h (), Text(p), Text( = 0.029), significantly (Fig. ), ReferencedContent(href=None, text=5), Text(), so that BMSCs reduced lung injury and inflammation via significant immunomodulatory properties and attenuated the severity of ARDS.), Figure(label=None, caption=None, text=))]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(Hounsfield units and volumes of the aerated and nonaerated areas of the right and left lungs were measured on CT scans. Quantitative estimation (the Hounsfield unit measurement) was done for different adjacent CT sections with the Leonardo workstation and software tools (Siemens). Lung parenchymal margins were manually demarcated, and then average Hounsfield units were obtained for each section. Also, the 3D pattern was observed for a better evaluation of the lung parenchyma (data not shown). These measurements demonstrated that Hounsfield units had increased 1 day after the experimental inflammation (before stromal cells therapy), which represents replacement of alveolar air with mucous and inflammatory cells (Fig. ), ReferencedContent(href=None, text=6), Text(). A significant decrease in the Hounsfield units was seen at 48 h (), Text(p), Text( = 0.032), 72 h (), Text(p), Text( = 0.036), and 168 h (), Text(p), Text( = 0.025) post-transplant, which indicates an increase in aerated volume of the lung in the treatment group. Also, variation volumes were compared and showed that total lung volume (aerated + nonaerated + tissue + edematous fluids) in both groups increased after ARDS, but transplant of BM-MSCs had decreased the process at 72 h (), Text(p), Text( = 0.047) and 168 h (), Text(p), Text( = 0.027). On CT scans, most nonaerated areas were observed in lower lobes in the caudoventral area (Fig. ), ReferencedContent(href=None, text=7), Text( and Additional file ), ReferencedContent(href=None, text=1), Text(: Table S7).), Figure(label=None, caption=None, text=), Figure(label=None, caption=None, text=))])]),
# Section(title='Section', content=[Paragraph(i=243, Text(The images and amounts of Doppler and M-mode echocardiographic parameters are shown in Additional file ), ReferencedContent(href=None, text=1), Text(: Figure S6. The amounts of BAL and plasma cytokines of rabbits are shown in Fig. ), ReferencedContent(href=None, text=6), Text( and Table ), ReferencedContent(href=None, text=2), Text(, respectively. Echocardiographic data showed no significant difference in the treatment group (BM-MSC recipients), but comparison of the two groups revealed that percentage ejection fraction at 72 h (), Text(p), Text( = 0.042) and 168 h (), Text(p), Text( = 0.038), percentage fractional shortening at 72 h (), Text(p), Text( = 0.049) and 168 h (), Text(p), Text( = 0.044), interventricular septal end diastole at 48 h (), Text(p), Text( = 0.014), 72 h (), Text(p), Text( = 0.038), and 168 h (), Text(p), Text( = 0.042), interventricular septal end systole at 24 h (), Text(p), Text( = 0.005), 48 h (), Text(p), Text( = 0.009), and 72 h (), Text(p), Text( = 0.010), left ventricular internal dimension systole at 72 h (), Text(p), Text( = 0.048) and 168 h (), Text(p), Text( = 0.022), aortic root diameter at 72 h (), Text(p), Text( = 0.027) and 168 h (), Text(p), Text( = 0.042), left atrial diameter at 168 h (), Text(p), Text( = 0.048), left ventricular outflow tract maximum velocity at 168 h (), Text(p), Text( = 0.041) and right ventricular outflow tract maximum velocity at 168 h (), Text(p), Text( = 0.039) had significant differences.), TableWrap(title=TableWrap, caption=None content=[Table(shape=(34, 9))]))]),
# Section(title='Section', content=[Paragraph(i=243, Text(The macroscopic examination of the lungs showed hyperemia, hemorrhage, emphysema, edema, and hepatization in the control group (Fig. ), ReferencedContent(href=None, text=8), Text(a), but brief hyperemia and edema were observed in the treatment group (Fig. ), ReferencedContent(href=None, text=8), Text(f). Sections of the lung demonstrated different histopathological patterns between the control and treatment groups. Microscopically, lungs showed more severe damage in the control group than the treatment group as hemorrhage in parenchyma and alveoli, moderate to severe vascular hyperemia, moderate to severe interstitial pneumonia, severe alveolar injuries and edema, neutrophilic margination in the capillary vessels, abundant presence of inflammatory cells, epithelial cells and other cell debris (cellularity) in interstitial spaces and alveoli, and thickness of the alveolar septum (Fig. ), ReferencedContent(href=None, text=8), Text(b–d). But treatment with BM-MSCs reduced the infiltration rate of inflammatory cells in the alveolar septum, hyperemia, hemorrhage, and edema, and lung structure was approximately normal and only slightly increased the thickness of the alveolar septum. Also, in most sections of the treatment group, injury in the bronchus, bronchioles, and vessels was not observed (Fig. ), ReferencedContent(href=None, text=8), Text(g–i).), Figure(label=None, caption=None, text=)), Paragraph(i=243, Text(In macroscopic observations of the heart, no lesions were found in both treatment and control groups, but in the microscopic examination of the heart sections in the control group, necroses were observed in a small number of myofibers (Fig. ), ReferencedContent(href=None, text=8), Text(e), whereas in treatment group, no injury was observed (Fig. ), ReferencedContent(href=None, text=8), Text(k).))])]),
# Section(title='Section', content=[Paragraph(i=243, Text(BM-MSCs are an ideal choice for cell therapy because there are fewer complications for cell isolation and also BM autologous cells that are capable of eliminating immune response and transplant rejection [), ReferencedContent(href=None, text=22), Text(]. MSCs have positive effects in the repair of ARDS [), ReferencedContent(href=None, text=23), Text(].)), Paragraph(i=243, Text(Although fibroblasts play a role in normal and pathological repair, and an accumulation of fibrocytes, fibroblasts, and myofibroblasts in the alveolar compartment, leading to excessive deposition components of the extracellular matrix but also according to prior findings the effect of them remains controversial [), ReferencedContent(href=None, text=23), Text(–), ReferencedContent(href=None, text=25), Text(] and unknown, so that reduction of its deposition or enhancement of its degradation could be treatment strategies. [), ReferencedContent(href=None, text=24), Text(])), Paragraph(i=243, Text(The results of this study showed that the BM-MSCs significantly decreased the severity of clinical symptoms induced by LPS, the number of inflammatory cells in blood and BAL, and balanced the values of arterial blood gases and cytokines. On the CT scans, a significant decrease in the Hounsfield units was observed, which is indicative of an increase in aerated volume of the lung in the treatment group. The echocardiographic parameters did not reveal a significant difference in the treatment group, and compared with the two groups together it was significant. Also, the histopathology demonstrated reduction in the infiltration of inflammatory cells and pulmonary hemorrhage and edema in the recipients of BM-MSCs.)), Paragraph(i=243, Text(In natural conditions, cells from bone marrow migrated to chemotactic gradients, but the amount of engraftment was low, and use of exogenous stromal cells can be helpful to this mechanism. The exact mechanisms of MSCs’ actions are not precise [), ReferencedContent(href=None, text=25), Text(], and sometimes the results of stromal cell research using animal models are incompatible with each other [), ReferencedContent(href=None, text=23), Text(]. However, three mechanisms have been defined for MSCs’ actions consisting of differentiation, cell–cell contact and paracrine function via the soluble factors [), ReferencedContent(href=None, text=25), Text(, ), ReferencedContent(href=None, text=26), Text(]. Researchers are likely to focus on manipulation of inflammatory pathways and optimizing lung repair while preventing ARDS progression [), ReferencedContent(href=None, text=6), Text(]; whereas management of inflammatory pathways forbids the development of ARDS, some researchers believe in the immunomodulatory effects of MSCs [), ReferencedContent(href=None, text=6), Text(]. Most trials have used local delivery of autologous BM-MSCs with the aim increasing the concentration of growth factors and cytokines in damaged tissue to improve possible engraftment and repair [), ReferencedContent(href=None, text=23), Text(]. For the first time, Gupta et al. reported effects of the local delivery of MSCs in ARDS that are consistent with this study [), ReferencedContent(href=None, text=26), Text(].)), Paragraph(i=243, Text(The anti-inflammatory role of MSCs may vary in humans and animals, but the useful effects of MSCs have been shown in several animal models [), ReferencedContent(href=None, text=27), Text(] and indicate the significant role of identification feature of MSCs [), ReferencedContent(href=None, text=22), Text(]. LPS of gram-negative bacterial wall binds to the CD14/TLR4/MD2 receptor complex, activating pathway and transcription of some inflammation- and apoptosis-related genes and activating innate immune response [), ReferencedContent(href=None, text=18), Text(, ), ReferencedContent(href=None, text=25), Text(] that produces the acute phase of ARDS. Therefore, the LPS-induced animal models ...
# Section(title='Section', content=[Paragraph(i=243, Text(Many studies on cell-based therapies in ARDS have been done, but most of them focused on molecular and signal tests. Although these studies could clear pathways, they are still far from tissue function. In this study, we tried to explain the MSCs’ effects on organ function. We investigated effects of BM-MSCs in an experimental model of ARDS and confirmed that MSCs decrease inflammation and improve alveolar fluid clearance and have a protective role in ARDS. Improvement in clinical signs, the decrease of inflammatory cells in blood and BAL, the balance in blood gases and cytokines, the decrease in the Hounsfield units, no changes in echocardiographic parameters. and the reduction of pulmonary hemorrhage and edema in pathology were observed. Despite these results, subsequent studies are required to confirm the decrease in inflammation, and physiological parameters over the long term and many experiments should be performed until stromal cell therapy is validated as a method of routine clinical treatment.))]),
# Section(title='Section', content=[
# Section(title='Section', content=[Paragraph(i=243, Text(
# ), NestedContainer(ReferencedContent(href=None, text=)), Text(
# ))])])]
# [('Section', []),
#  ('Section',
#   ['Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section']),
#  ('Section',
#   ['Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section',
#    'Section']),
#  ('Section', []),
#  ('Section', []),
#  ('Section', ['Section'])]
